# %%
import pandas as pd
import numpy as np

# %%
cand = pd.read_csv("candidate_data.csv")
job = pd.read_csv("job_data.csv")
job.head()
# Out:
#    jobid                       title  \
# 0     26             Sr. UI Engineer
# 1     46              Head of Design
# 2     47  Lead Product Designer, UxD
# 3     27    Senior Frontend Engineer
# 4     28   Team Lead, UI Development
#
#                                primaryresponsibility primaryperks  \
# 0  <p>We’re looking for an addition to our full-s...          NaN
# 1  <ul><li>Lead new creative and holistic thinkin...          NaN
# 2  BrowerStack is looking for an exceptionally ta...          NaN
# 3  <p>RedBus seeks an experienced UI Developer, w...          NaN
# 4  <p>RedBus seeks an experienced UI Architect, t...          NaN
#
#                                   primaryrequirement          datecreated  \
# 0  <ul><li>At least 3 years of experience</li><li...  2017-01-15 18:00:53
# 1  <ul><li>4 or more years industry experience in...  2017-01-15 18:00:53
# 2  <p>UX Design</p><ul><li>Should have experience...  2017-01-15 18:00:53
# ...

# %%
#Code to filter out candidates based on criteria of a particular job
#Here in this case, we aref iltering out based on the criteria of number of years of experience required
minexp = cand['experience'] > 12
maxexp = cand['experience'] < 96
cand1 = cand[ minexp & maxexp]
cand1
# Out:
#      userid                      name  noticeperiod  experience  annualctc  \
# 0      3749             Varad Kaushik            15          52     400000
# 1      6081  Chandrakanth Jamanjyothi            30          24     280000
# 3      6055              Ashish Rajak            15          77     620000
# 4      6083               Aniket Sase            15          31     600000
# 5      4768         Sridhar Rajendran            15          89    1300000
# 9      6089         Mohammed Sarafath            15          24     300000
# 11     6091             Divya Barsode            15          36     700000
# 13     6092            Shweta Goswami            30          88    1150000
# 14     5573             Shashank Sood            30          38     500000
# 15     2225               Vikas Kumar            15          33     650000
# 19     6109              nancy sihmar            30          18     890000
# ...

# %%
#Output the required file
cand1.to_csv("cand1.csv")

# %%
df1[['col1','educationdetaiolsstart','col2', 'endyearofeducation', 'nameofcollege']] = df1['companytypepreferences'].str.rsplit('-', expand=True)
df1.drop(['educationdetails'], axis=1, inplace=True);
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-29-9a27246b9e99> in <module>()
# ----> 1 df1[['col1','educationdetaiolsstart','col2', 'endyearofeducation', 'nameofcollege']] = df1['companytypepreferences'].str.rsplit('-', expand=True)
#       2 df1.drop(['educationdetails'], axis=1, inplace=True);
#
# E:\CrewKarma\servers\pythonenv\lib\site-packages\pandas\core\frame.pyc in __setitem__(self, key, value)
#    2412
#    2413         if isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2414             self._setitem_array(key, value)
#    2415         elif isinstance(key, DataFrame):
#    2416             self._setitem_frame(key, value)
#
# E:\CrewKarma\servers\pythonenv\lib\site-packages\pandas\core\frame.pyc in _setitem_array(self, key, value)
#    2436             if isinstance(value, DataFrame):
#    2437                 if len(value.columns) != len(key):
# -> 2438                     raise ValueError('Columns must be same length as key')
# ...
